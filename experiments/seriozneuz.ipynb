# %%
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# inicializujeme knižnicu seaborn
sns.set()

# %%
data = pd.read_csv("learning_traces.13m.csv")
data
# Out:
#           p_recall   timestamp     delta user_id learning_language  \
# 0         1.000000  1362076081  27649635    u:FO                de
# 1         0.500000  1362076081  27649635    u:FO                de
# 2         1.000000  1362076081  27649635    u:FO                de
# 3         0.500000  1362076081  27649635    u:FO                de
# 4         1.000000  1362076081  27649635    u:FO                de
# ...            ...         ...       ...     ...               ...
# 12854221  0.800000  1363104897       368  u:i5D8                en
# 12854222  0.800000  1363104897       368  u:i5D8                en
# 12854223  1.000000  1363104897       368  u:i5D8                en
# 12854224  0.600000  1363104897       368  u:i5D8                en
# 12854225  0.666667  1363104897       368  u:i5D8                en
#
#          ui_language                         lexeme_id  \
# 0                 en  76390c1350a8dac31186187e2fe1e178
# ...

# %%
#preskalovanie delty na hodiny
data["delta"] = (data["delta"] / (60 * 60))
data
# Out:
#           p_recall   timestamp        delta user_id learning_language  \
# 0         1.000000  1362076081  7680.454167    u:FO                de
# 1         0.500000  1362076081  7680.454167    u:FO                de
# 2         1.000000  1362076081  7680.454167    u:FO                de
# 3         0.500000  1362076081  7680.454167    u:FO                de
# 4         1.000000  1362076081  7680.454167    u:FO                de
# ...            ...         ...          ...     ...               ...
# 12854221  0.800000  1363104897     0.102222  u:i5D8                en
# 12854222  0.800000  1363104897     0.102222  u:i5D8                en
# 12854223  1.000000  1363104897     0.102222  u:i5D8                en
# 12854224  0.600000  1363104897     0.102222  u:i5D8                en
# 12854225  0.666667  1363104897     0.102222  u:i5D8                en
#
#          ui_language                         lexeme_id  \
# 0                 en  76390c1350a8dac31186187e2fe1e178
# ...

# %%
data.head(50)
# Out:
#     p_recall   timestamp        delta user_id learning_language ui_language  \
# 0   1.000000  1362076081  7680.454167    u:FO                de          en
# 1   0.500000  1362076081  7680.454167    u:FO                de          en
# 2   1.000000  1362076081  7680.454167    u:FO                de          en
# 3   0.500000  1362076081  7680.454167    u:FO                de          en
# 4   1.000000  1362076081  7680.454167    u:FO                de          en
# 5   1.000000  1362076081  7680.454167    u:FO                de          en
# 6   1.000000  1362076081  7680.454167    u:FO                de          en
# 7   1.000000  1362082032   123.446389  u:dDwF                es          en
# 8   1.000000  1362082044     1.656389    u:FO                de          en
# 9   0.750000  1362082044     1.656389    u:FO                de          en
# 10  0.888889  1362082044     1.656389    u:FO                de          en
# ...

# %%
print(len(data.groupby("timestamp")))
# Out:
# 574814

# %%
recall_percentages = data.groupby('session_seen')['p_recall'].apply(lambda x: (x==1).mean()*100)
print(recall_percentages)
# Out:
# session_seen
# 1     88.393927
# 2     83.024747
# 3     77.619990
# 4     70.984790
# 5     64.652256
# 6     59.742639
# 7     55.268031
# 8     51.634048
# 9     47.748860
# 10    46.687672
# 11    42.209590
# 12    38.938505
# 13    35.091278
# 14    32.780382
# 15    30.520305
# 16    31.687641
# 17    32.920792
# 18    32.335329
# 19    27.520436
# 20    22.485207
# Name: p_recall, dtype: float64

# %%
data[data["session_seen"]==20]
# Out:
#           p_recall   timestamp       delta user_id learning_language  \
# 19841         0.85  1362083575    0.108611   u:YVz                en
# 45579         0.90  1362084807    3.559444  u:drdU                de
# 73404         0.95  1362086153    0.118611  u:h72e                en
# 193083        0.85  1362092298   26.208333  u:bqJp                es
# 201448        0.85  1362092758    0.173333  u:hhMQ                en
# ...            ...         ...         ...     ...               ...
# 12572691      0.95  1363077562    0.080278  u:idSl                pt
# 12586466      0.90  1363080060  145.210556  u:hRAU                es
# 12633204      0.85  1363086438   40.244722  u:hSWF                pt
# 12791879      0.95  1363100893    0.043611  u:gonm                en
# 12836029      0.65  1363103712    0.045000  u:gJXZ                en
#
#          ui_language                         lexeme_id  \
# 19841             es  d241cf80b2938ee47c4bc4ebfc77930d
# ...

# %%
print(pd.value_counts(data.groupby("user_id")["timestamp"]).head(100000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print(pd.value_counts(data.groupby("user_id")["timestamp"]).head(100000))
#
# File c:\users\hresk\pycharmprojects\bakalarka\venv\lib\site-packages\pandas\core\algorithms.py:990, in value_counts(values, sort, ascending, normalize, bins, dropna)
#     988 else:
#     989     values = _ensure_arraylike(values)
# --> 990     keys, counts = value_counts_arraylike(values, dropna)
#     992     # For backwards compatibility, we let Index do its normal type
#     993     #  inference, _except_ for if if infers from object to bool.
#     994     idx = Index._with_infer(keys)
#
# File c:\users\hresk\pycharmprojects\bakalarka\venv\lib\site-packages\pandas\core\algorithms.py:1026, in value_counts_arraylike(values, dropna, mask)
#    1013 """
#    1014 Parameters
#    1015 ----------
#    (...)
# ...

# %%
print(pd.value_counts(data["p_recall"]).head(10))
# Out:
# 1.000000    10782942
# 0.000000      906340
# 0.500000      449133
# 0.666667      288656
# 0.750000      169363
# 0.800000       94498
# 0.833333       45008
# 0.333333       27389
# 0.857143       21399
# 0.600000       19797
# Name: p_recall, dtype: int64

# %%
display(pd.value_counts(data[data["timestamp"]==1362517776]["lexeme_string"]))
# Out:
# a/a<det><ind><sg>                   5
# we/prpers<prn><subj><p1><mf><pl>    4
# woman/woman<n><sg>                  4
# and/and<cnjcoo>                     3
# am/be<vbser><pri><p1><sg>           3
#                                    ..
# turtles/turtle<n><pl>               1
# birds/bird<n><pl>                   1
# rice/rice<n><sg>                    1
# ducks/duck<n><pl>                   1
# su/suyo<det><pos><mf><sg>           1
# Name: lexeme_string, Length: 180, dtype: int64

# %%
x=data[data["timestamp"]==1362517776]

display(x[x["lexeme_string"]=="and/and<cnjcoo>"])
# Out:
#          p_recall   timestamp     delta user_id learning_language ui_language  \
# 5495460       1.0  1362517776  0.117222  u:fWqs                en          pt
# 5495550       1.0  1362517776  0.101389  u:ii1B                en          es
# 5495689       0.5  1362517776  6.385278  u:h8CF                en          it
#
#                                 lexeme_id    lexeme_string  history_seen  \
# 5495460  0d9244f805fd55af1281a1bcb1a2cba6  and/and<cnjcoo>            13
# 5495550  0d9244f805fd55af1281a1bcb1a2cba6  and/and<cnjcoo>            45
# 5495689  0d9244f805fd55af1281a1bcb1a2cba6  and/and<cnjcoo>            28
#
#          history_correct  session_seen  session_correct
# 5495460               11             1                1
# 5495550               43             1                1
# 5495689               22             2                1
